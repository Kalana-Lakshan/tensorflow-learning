# %% [markdown]
# <a href="https://colab.research.google.com/github/Kalana-Lakshan/tensorflow-learning/blob/main/tf_notebook1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.19.0'

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
# !nvidia-smi
# Out:
# Wed Dec 24 02:34:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0             29W /   70W |     102MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install opendatasets

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/andonians/random-linear-regression")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: kalanalakshan
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/andonians/random-linear-regression
# ...
# 100%|██████████| 7.63k/7.63k [00:00<00:00, 28.4MB/s]

# %%
data = pd.read_csv("random-linear-regression/test.csv")

# %%
data.head()
# Out:
#     x          y
# 0  77  79.775152
# 1  21  23.177279
# 2  22  25.609262
# 3  20  17.857388
# 4  36  41.849864

# %%
x = data["x"]
y = data["y"]

# %%
x
# Out:
# 0      77
# 1      21
# 2      22
# 3      20
# 4      36
#        ..
# 295    71
# 296    46
# 297    55
# 298    62
# 299    47
# Name: x, Length: 300, dtype: int64

# %%
y
# Out:
# 0      79.775152
# 1      23.177279
# 2      25.609262
# 3      17.857388
# 4      41.849864
#          ...
# 295    68.545888
# 296    47.334876
# 297    54.090637
# 298    63.297171
# 299    52.459467
# Name: y, Length: 300, dtype: float64

# %%
plt.scatter(x,y,c='g')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
plt.scatter(x_train,y_train,c="b",label="training_data")
plt.scatter(x_test,y_test,c="y",label="testing_data")
plt.legend()
plt.show()

# %% [markdown]
# Model Building
